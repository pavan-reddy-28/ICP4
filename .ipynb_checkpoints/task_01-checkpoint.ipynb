# %%
import pandas as pd
dataFile = pd.read_csv("./data.csv")
dataFile.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
#  Check if the data has null values.
#  Replace the null values with the mean
print(dataFile.isnull())
dataFile = dataFile.fillna(df.mean())
dataFile
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# ...

# %%
dataFile.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
# Select at least two columns and aggregate the data using: min, max, count, mean.

result = dataFile.groupby('Pulse').agg({'Maxpulse': ['min', 'max','count','mean']})
  
print("Mean, min, and max values of Duration grouped by Pulse")
result
# Out:
# Mean, min, and max values of Duration grouped by Pulse
#       Maxpulse
#            min  max count        mean
# Pulse
# 80         100  120     2  110.000000
# 83         107  107     1  107.000000
# 85         120  120     1  120.000000
# 90         100  130    12  114.416667
# 92         108  118     3  113.666667
# 93         113  128     3  121.666667
# 95         112  130     3  123.333333
# 97         122  131     7  126.428571
# 98         120  126     6  123.333333
# 99         119  125     2  122.000000
# 100        119  157    19  125.684211
# 101        124  127     2  125.500000
# 102        124  136     6  128.166667
# 103        123  147     9  132.888889
# 104        129  134     4  132.250000
# 105        125  140     6  132.333333
# 106        126  136     6  131.000000
# 107        124  138     8  133.000000
# 108        129  160     7  140.000000
# 109        127  175     9  141.555556
# 110        130  150     7  138.428571
# ...

# %%
filter1 = dataFile[(dataFile.Calories >= 500) & (dataFile.Calories <= 1000)]
filter1
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
filter2 = dataFile[(dataFile.Calories > 500) & (dataFile.Pulse < 100)]
filter2
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_modified = dataFile.loc[:, dataFile.columns!='Maxpulse']
df_modified.head()
# Out:
#    Duration  Pulse  Calories
# 0        60    110     409.1
# 1        60    117     479.0
# 2        60    103     340.0
# 3        45    109     282.4
# 4        45    117     406.0

# %%
dataFile.dtypes
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
dataFile.Calories = dataFile.Calories.astype(int)
dataFile.dtypes
# Out:
# Duration    int64
# Pulse       int64
# Maxpulse    int64
# Calories    int64
# dtype: object

# %%
import matplotlib.pyplot as plt
# Create scatter plot
plt.scatter(dataFile['Duration'],dataFile['Calories'] )
plt.xlabel('Duration')
plt.ylabel('Calories')
plt.title('Scatter plot of columns Duration and Calories')
plt.show()
